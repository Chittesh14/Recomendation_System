# %%
import requests
import pandas as pd
import numpy as np
import json

# %%
baseurl='https://api.tvmaze.com/shows'
num=0;
endpoint=f'?page={num}'
r=requests.get(baseurl+endpoint).json()
df=pd.DataFrame(r)

# %%
#add to df
i=1
for i in range (1,26):
  num=i
  endpoint=f'?page={num}'
  r=requests.get(baseurl+endpoint).json()
  print('req'+str(i))
  df2=pd.DataFrame(r)
  i+=1
  df=df.append(df2,ignore_index=True)
# Out:
# req1
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\3126435855.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)
# req2
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\3126435855.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)
# req3
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\3126435855.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)
# req4
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\3126435855.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)
# ...

# %%
val=df

# %%
backup=df

# %%
df.tail()
# Out:
#         id                                                url  \
# 6133  6495           https://www.tvmaze.com/shows/6495/pocoyo
# 6134  6496           https://www.tvmaze.com/shows/6496/popeye
# 6135  6497  https://www.tvmaze.com/shows/6497/worzel-gummidge
# 6136  6498        https://www.tvmaze.com/shows/6498/hale-pace
# 6137  6499    https://www.tvmaze.com/shows/6499/eerie-indiana
#
#                  name       type language                   genres status  \
# 6133           Pocoyo  Animation  English               [Children]  Ended
# 6134           Popeye  Animation  English                       []  Ended
# 6135  Worzel Gummidge   Scripted  English  [Drama, Comedy, Family]  Ended
# 6136      Hale & Pace   Scripted  English                 [Comedy]  Ended
# 6137   Eerie, Indiana   Scripted  English                       []  Ended
#
#       runtime  averageRuntime   premiered  ...             rating weight  \
# ...

# %%
df.shape
# Out:
# (6138, 23)

# %%
import pickle

# %%
pickle.dump(df.to_dict,open('tvmazedata.pkl','wb'))

# %%
#finding the no of pages
#i=0
#for i in range (260):
 # if(df[0]['id']):
  #   num=i
   #  endpoint=f'?page={num}'
  #   r=requests.get(baseurl+endpoint).json()
  #   print('req'+str(i))
   #  df2=pd.DataFrame(r)
   #  i+=1
  #   df=df.append(df2,ignore_index=True)
 # else:
   # break

# %%
#name,id,type,genres,summary for processing

# %%
df.shape
# Out:
# (6138, 23)

# %%
#check count of each type
df['type'].value_counts()
# Out:
# Scripted       3160
# Reality        1095
# Documentary     729
# Animation       665
# Talk Show       148
# Game Show       130
# Variety         121
# Sports           31
# News             30
# Panel Show       26
# Award Show        3
# Name: type, dtype: int64

# %%
df=df[['id','name','type','genres','summary']]

# %%
df.head()
# Out:
#    id                name      type                              genres  \
# 0   1      Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  Scripted    [Action, Crime, Science-Fiction]
# 2   3              Bitten  Scripted            [Drama, Horror, Romance]
# 3   4               Arrow  Scripted    [Drama, Action, Science-Fiction]
# 4   5      True Detective  Scripted            [Drama, Crime, Thriller]
#
#                                              summary
# 0  <p><b>Under the Dome</b> is the story of a sma...
# 1  <p>You are being watched. The government has a...
# 2  <p>Based on the critically acclaimed series of...
# 3  <p>After a violent shipwreck, billionaire play...
# 4  <p>Touch darkness and darkness touches you bac...

# %%
df.isnull().sum()
# Out:
# id          0
# name        0
# type        0
# genres      0
# summary    90
# dtype: int64

# %%
selected=['id','name','type','genres','summary']

# %%
for feature in selected:
  df[feature]=df[feature].fillna('')
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\522659402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[feature]=df[feature].fillna('')

# %%
df.head()
# Out:
#    id                name      type                              genres  \
# 0   1      Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  Scripted    [Action, Crime, Science-Fiction]
# 2   3              Bitten  Scripted            [Drama, Horror, Romance]
# 3   4               Arrow  Scripted    [Drama, Action, Science-Fiction]
# 4   5      True Detective  Scripted            [Drama, Crime, Thriller]
#
#                                              summary
# 0  <p><b>Under the Dome</b> is the story of a sma...
# 1  <p>You are being watched. The government has a...
# 2  <p>Based on the critically acclaimed series of...
# 3  <p>After a violent shipwreck, billionaire play...
# 4  <p>Touch darkness and darkness touches you bac...

# %%
df.head()
# Out:
#    id                name      type                              genres  \
# 0   1      Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  Scripted    [Action, Crime, Science-Fiction]
# 2   3              Bitten  Scripted            [Drama, Horror, Romance]
# 3   4               Arrow  Scripted    [Drama, Action, Science-Fiction]
# 4   5      True Detective  Scripted            [Drama, Crime, Thriller]
#
#                                              summary
# 0  <p><b>Under the Dome</b> is the story of a sma...
# 1  <p>You are being watched. The government has a...
# 2  <p>Based on the critically acclaimed series of...
# 3  <p>After a violent shipwreck, billionaire play...
# 4  <p>Touch darkness and darkness touches you bac...

# %%
#all are strings
df.iloc[0]['name']
# Out:
# 'Under the Dome'

# %%
df.head(1)
# Out:
#    id            name      type                              genres  \
# 0   1  Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
#
#                                              summary
# 0  <p><b>Under the Dome</b> is the story of a sma...

# %%
temp=df['summary'][1]

# %%
temp2=df

# %%
import re

# %%
#pattern=re.compile('<.*?>')

# %%
#def cleanhtml(temp):
  #cleantext = re.sub(pattern, '', temp)         #temp=        
  #return(cleantext)

# %%
#df['summary']=df['summary'].apply(cleanhtml)

# %%
#df['summary']

# %%
#df=backup

# %%
df.head()
# Out:
#    id                name      type                              genres  \
# 0   1      Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  Scripted    [Action, Crime, Science-Fiction]
# 2   3              Bitten  Scripted            [Drama, Horror, Romance]
# 3   4               Arrow  Scripted    [Drama, Action, Science-Fiction]
# 4   5      True Detective  Scripted            [Drama, Crime, Thriller]
#
#                                              summary
# 0  <p><b>Under the Dome</b> is the story of a sma...
# 1  <p>You are being watched. The government has a...
# 2  <p>Based on the critically acclaimed series of...
# 3  <p>After a violent shipwreck, billionaire play...
# 4  <p>Touch darkness and darkness touches you bac...

# %%
df.isnull().sum()
# Out:
# id         0
# name       0
# type       0
# genres     0
# summary    0
# dtype: int64

# %%
df
# Out:
#         id                name       type                              genres  \
# 0        1      Under the Dome   Scripted  [Drama, Science-Fiction, Thriller]
# 1        2  Person of Interest   Scripted    [Action, Crime, Science-Fiction]
# 2        3              Bitten   Scripted            [Drama, Horror, Romance]
# 3        4               Arrow   Scripted    [Drama, Action, Science-Fiction]
# 4        5      True Detective   Scripted            [Drama, Crime, Thriller]
# ...    ...                 ...        ...                                 ...
# 6133  6495              Pocoyo  Animation                          [Children]
# 6134  6496              Popeye  Animation                                  []
# 6135  6497     Worzel Gummidge   Scripted             [Drama, Comedy, Family]
# 6136  6498         Hale & Pace   Scripted                            [Comedy]
# 6137  6499      Eerie, Indiana   Scripted                                  []
#
# ...

# %%
#df.iloc[61000]['summary']
# Out:
# '<p>The miniseries is set in a Villa miseria in Greater Buenos Aires, ruled by mayor Iñíguez since 1987. Pablo Aldo Perotti, known as the "Gitano", works in the clientelist relation between the poor people and the political authorities. Perotti wants to be the new mayor, and to return with his former wife Clarita.</p>'

# %%
#cleanhtml(temp)
# Out:
# You are being watched. The government has a secret system, a machine that spies on you every hour of every day. I know because I built it. I designed the Machine to detect acts of terror but it sees everything. Violent crimes involving ordinary people. People like you. Crimes the government considered "irrelevant". They wouldn't act so I decided I would. But I needed a partner. Someone with the skills to intervene. Hunted by the authorities, we work in secret. You'll never find us. But victim or perpetrator, if your number is up, we'll find you.

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup('<p>The miniseries is set in a Villa miseria in Greater Buenos Aires, ruled by mayor Iñíguez since 1987. Pablo Aldo Perotti, known as the "Gitano", works in the clientelist relation between the poor people and the political authorities. Perotti wants to be the new mayor, and to return with his former wife Clarita.</p>')
text = soup.get_text()
print(text)
# Out:
# The miniseries is set in a Villa miseria in Greater Buenos Aires, ruled by mayor Iñíguez since 1987. Pablo Aldo Perotti, known as the "Gitano", works in the clientelist relation between the poor people and the political authorities. Perotti wants to be the new mayor, and to return with his former wife Clarita.

# %%
def htmltagsremover(text):
    soup=BeautifulSoup(text)
    text=soup.get_text()
    return text

# %%
#htmltagsremover(df)

# %%
df['summary']=df['summary'].apply(htmltagsremover)
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\1738309021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['summary']=df['summary'].apply(htmltagsremover)

# %%
df['summary']
# Out:
# 0       Under the Dome is the story of a small town th...
# 1       You are being watched. The government has a se...
# 2       Based on the critically acclaimed series of no...
# 3       After a violent shipwreck, billionaire playboy...
# 4       Touch darkness and darkness touches you back. ...
#                               ...
# 6133    Meet Pocoyo, an unforgettable little boy with ...
# 6134    Popeye started out as a character in the daily...
# 6135    Based on the children's books by Barbara Eupha...
# 6136    Sketch comedy series starring Gareth Hale and ...
# 6137    Marshall Teller is a young boy who moves with ...
# Name: summary, Length: 6138, dtype: object

# %%
df.head(1)
# Out:
#    id            name      type                              genres  \
# 0   1  Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
#
#                                              summary
# 0  Under the Dome is the story of a small town th...

# %%
df['summary'][0]
# Out:
# "Under the Dome is the story of a small town that is suddenly and inexplicably sealed off from the rest of the world by an enormous transparent dome. The town's inhabitants must deal with surviving the post-apocalyptic conditions while searching for answers about the dome, where it came from and if and when it will go away."

# %%
#list conversion of summary
df['summary']=df['summary'].apply(lambda x:x.split())
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\4144754834.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['summary']=df['summary'].apply(lambda x:x.split())

# %%
df['summary']
# Out:
# 0       [Under, the, Dome, is, the, story, of, a, smal...
# 1       [You, are, being, watched., The, government, h...
# 2       [Based, on, the, critically, acclaimed, series...
# 3       [After, a, violent, shipwreck,, billionaire, p...
# 4       [Touch, darkness, and, darkness, touches, you,...
#                               ...
# 6133    [Meet, Pocoyo,, an, unforgettable, little, boy...
# 6134    [Popeye, started, out, as, a, character, in, t...
# 6135    [Based, on, the, children's, books, by, Barbar...
# 6136    [Sketch, comedy, series, starring, Gareth, Hal...
# 6137    [Marshall, Teller, is, a, young, boy, who, mov...
# Name: summary, Length: 6138, dtype: object

# %%
df.head(1)
# Out:
#    id            name      type                              genres  \
# 0   1  Under the Dome  Scripted  [Drama, Science-Fiction, Thriller]
#
#                                              summary
# 0  [Under, the, Dome, is, the, story, of, a, smal...

# %%
#list conversion
df['type']=df['type'].apply(lambda x:x.split())
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\2986704128.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type']=df['type'].apply(lambda x:x.split())

# %%
df.head()
# Out:
#    id                name        type                              genres  \
# 0   1      Under the Dome  [Scripted]  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  [Scripted]    [Action, Crime, Science-Fiction]
# 2   3              Bitten  [Scripted]            [Drama, Horror, Romance]
# 3   4               Arrow  [Scripted]    [Drama, Action, Science-Fiction]
# 4   5      True Detective  [Scripted]            [Drama, Crime, Thriller]
#
#                                              summary
# 0  [Under, the, Dome, is, the, story, of, a, smal...
# 1  [You, are, being, watched., The, government, h...
# 2  [Based, on, the, critically, acclaimed, series...
# 3  [After, a, violent, shipwreck,, billionaire, p...
# 4  [Touch, darkness, and, darkness, touches, you,...

# %%
#adding all fields into tags
df['tags']=df['type']+df['genres']+df['summary']
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\1284805035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['type']+df['genres']+df['summary']

# %%
df.head()
# Out:
#    id                name        type                              genres  \
# 0   1      Under the Dome  [Scripted]  [Drama, Science-Fiction, Thriller]
# 1   2  Person of Interest  [Scripted]    [Action, Crime, Science-Fiction]
# 2   3              Bitten  [Scripted]            [Drama, Horror, Romance]
# 3   4               Arrow  [Scripted]    [Drama, Action, Science-Fiction]
# 4   5      True Detective  [Scripted]            [Drama, Crime, Thriller]
#
#                                              summary  \
# 0  [Under, the, Dome, is, the, story, of, a, smal...
# 1  [You, are, being, watched., The, government, h...
# 2  [Based, on, the, critically, acclaimed, series...
# 3  [After, a, violent, shipwreck,, billionaire, p...
# 4  [Touch, darkness, and, darkness, touches, you,...
#
#                                                 tags
# 0  [Scripted, Drama, Science-Fiction, Thriller, U...
# 1  [Scripted, Action, Crime, Science-Fiction, You...
# ...

# %%
#creating new df
new_df=df[['id','name','tags']]

# %%
new_df
# Out:
#         id                name  \
# 0        1      Under the Dome
# 1        2  Person of Interest
# 2        3              Bitten
# 3        4               Arrow
# 4        5      True Detective
# ...    ...                 ...
# 6133  6495              Pocoyo
# 6134  6496              Popeye
# 6135  6497     Worzel Gummidge
# 6136  6498         Hale & Pace
# 6137  6499      Eerie, Indiana
#
#                                                    tags
# 0     [Scripted, Drama, Science-Fiction, Thriller, U...
# 1     [Scripted, Action, Crime, Science-Fiction, You...
# 2     [Scripted, Drama, Horror, Romance, Based, on, ...
# 3     [Scripted, Drama, Action, Science-Fiction, Aft...
# 4     [Scripted, Drama, Crime, Thriller, Touch, dark...
# ...                                                 ...
# 6133  [Animation, Children, Meet, Pocoyo,, an, unfor...
# 6134  [Animation, Popeye, started, out, as, a, chara...
# 6135  [Scripted, Drama, Comedy, Family, Based, on, t...
# ...

# %%
#converting tags to strings
new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\951666539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#    id                name                                               tags
# 0   1      Under the Dome  Scripted Drama Science-Fiction Thriller Under ...
# 1   2  Person of Interest  Scripted Action Crime Science-Fiction You are ...
# 2   3              Bitten  Scripted Drama Horror Romance Based on the cri...
# 3   4               Arrow  Scripted Drama Action Science-Fiction After a ...
# 4   5      True Detective  Scripted Drama Crime Thriller Touch darkness a...

# %%
#converting everything to lower
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\3512285102.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    id                name                                               tags
# 0   1      Under the Dome  scripted drama science-fiction thriller under ...
# 1   2  Person of Interest  scripted action crime science-fiction you are ...
# 2   3              Bitten  scripted drama horror romance based on the cri...
# 3   4               Arrow  scripted drama action science-fiction after a ...
# 4   5      True Detective  scripted drama crime thriller touch darkness a...

# %%
#max_features=max no of words,stop_words=words like is am are the
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
#most of the values will be a 0 hence there are 5000 words the out put will be a sparce matrix
vectors.shape
# Out:
# (6138, 5000)

# %%
cv.get_feature_names()
# Out:
# C:\Users\chittu\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '13th',
#  '14',
#  '15',
#  '150',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '19',
#  '1930s',
#  '1950s',
#  '1960s',
#  '1963',
#  '1968',
#  '1969',
#  '1970s',
#  '1973',
#  '1979',
#  '1980',
#  '1980s',
#  '1985',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1993',
#  '1994',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '23',
#  '24',
#  '25',
#  '250',
#  '26',
# ...

# %%
#stemming removing words like [love,loving,loves]
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
new_df['tags']
# Out:
# 0       scripted drama science-fiction thriller under ...
# 1       scripted action crime science-fiction you are ...
# 2       scripted drama horror romance based on the cri...
# 3       scripted drama action science-fiction after a ...
# 4       scripted drama crime thriller touch darkness a...
#                               ...
# 6133    animation children meet pocoyo, an unforgettab...
# 6134    animation popeye started out as a character in...
# 6135    scripted drama comedy family based on the chil...
# 6136    scripted comedy sketch comedy series starring ...
# 6137    scripted marshall teller is a young boy who mo...
# Name: tags, Length: 6138, dtype: object

# %%
def stem(text):
  y=[]
  for i in text.split():
     y.append(ps.stem(i))
  return " ".join(y)

# %%
stem("Scripted Drama Crime Thriller Criminal Minds revolves around an elite team of FBI profilers who analyze the country's most twisted criminal minds, anticipating their next moves before they strike again.")
# Out:
# "script drama crime thriller crimin mind revolv around an elit team of fbi profil who analyz the country' most twist crimin minds, anticip their next move befor they strike again."

# %%
ps.stem('actors')
# Out:
# 'actor'

# %%
#applying stem to entire tags column
new_df['tags']=new_df['tags'].apply(stem)
# Out:
# C:\Users\chittu\AppData\Local\Temp\ipykernel_2256\453512694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(stem)

# %%
new_df.iloc[-1]['tags']
# Out:
# 'script marshal teller is a young boy who move with hi famili to the small town of eerie, which he soon discov is the focu of all sort of strang and inexplic events, and is inhabit by oddballs, weirdos, and even elvi presley. along with hi best friend simon, marshal investig and collect evid about hi weird new home town.'

# %%
new_df['tags'][1]
# Out:
# 'script action crime science-fict you are be watched. the govern ha a secret system, a machin that spi on you everi hour of everi day. i know becaus i built it. i design the machin to detect act of terror but it see everything. violent crime involv ordinari people. peopl like you. crime the govern consid "irrelevant". they wouldn\'t act so i decid i would. but i need a partner. someon with the skill to intervene. hunt by the authorities, we work in secret. you\'ll never find us. but victim or perpetrator, if your number is up, we\'ll find you.'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '13th',
#  '14',
#  '15',
#  '150',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '19',
#  '1945',
#  '1950',
#  '1960',
#  '1960s',
#  '1963',
#  '1965',
#  '1968',
#  '1969',
#  '1970',
#  '1970s',
#  '1973',
#  '1978',
#  '1979',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '23',
#  '24',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '29',
#  '30',
#  '300',
#  '31',
#  '35',
#  '3d',
#  '40',
#  '400',
#  '48',
#  '50',
#  '500',
#  '60',
#  '600',
#  '70',
#  '80',
#  '90',
#  '9pm',
#  'aaron',
# ...

# %%
vectors.shape
# Out:
# (6138, 5000)

# %%
#cant use euclidian distance for such precision hence cosine distance 0 between the two vectors is calculated
#distance is inversely proportional to the similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
final=cosine_similarity(vectors)

# %%
final
# Out:
# array([[1.        , 0.07216878, 0.15294382, ..., 0.04536092, 0.06085806,
#         0.24343225],
#        [0.07216878, 1.        , 0.01655665, ..., 0.05892557, 0.03952847,
#         0.01976424],
#        [0.15294382, 0.01655665, 1.        , ..., 0.1717074 , 0.08377078,
#         0.08377078],
#        ...,
#        [0.04536092, 0.05892557, 0.1717074 , ..., 1.        , 0.1490712 ,
#         0.0931695 ],
#        [0.06085806, 0.03952847, 0.08377078, ..., 0.1490712 , 1.        ,
#         0.05      ],
#        [0.24343225, 0.01976424, 0.08377078, ..., 0.0931695 , 0.05      ,
#         1.        ]])

# %%
final[1]
# Out:
# array([0.07216878, 1.        , 0.01655665, ..., 0.05892557, 0.03952847,
#        0.01976424])

# %%
new_df.head()
# Out:
#    id                name                                               tags
# 0   1      Under the Dome  script drama science-fict thriller under the d...
# 1   2  Person of Interest  script action crime science-fict you are be wa...
# 2   3              Bitten  script drama horror romanc base on the critic ...
# 3   4               Arrow  script drama action science-fict after a viole...
# 4   5      True Detective  script drama crime thriller touch dark and dar...

# %%
new_df[new_df['name']=='Arrow'].index[0]
# Out:
# 3

# %%
movies=[]

# %%
#finding recomendations
def recomend(movie):
  movie_ind=new_df[new_df['name']==movie].index[0]
  distances=final[movie_ind]   #particular row in similarity
  movie_lst=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
  movies=[]
  for i in movie_lst:          #use movie index for i
    movies.append(new_df.iloc[i[0]][1])
    print(new_df.iloc[i[0]][1])
  return movies

 # for i in range(0,5):
  #  id_lst.append(movie_lst[i][0])
  #  i+=1

# %%
val
# Out:
#         id                                                url  \
# 0        1      https://www.tvmaze.com/shows/1/under-the-dome
# 1        2  https://www.tvmaze.com/shows/2/person-of-interest
# 2        3              https://www.tvmaze.com/shows/3/bitten
# 3        4               https://www.tvmaze.com/shows/4/arrow
# 4        5      https://www.tvmaze.com/shows/5/true-detective
# ...    ...                                                ...
# 6133  6495           https://www.tvmaze.com/shows/6495/pocoyo
# 6134  6496           https://www.tvmaze.com/shows/6496/popeye
# 6135  6497  https://www.tvmaze.com/shows/6497/worzel-gummidge
# 6136  6498        https://www.tvmaze.com/shows/6498/hale-pace
# 6137  6499    https://www.tvmaze.com/shows/6499/eerie-indiana
#
#                     name       type language  \
# 0         Under the Dome   Scripted  English
# 1     Person of Interest   Scripted  English
# 2                 Bitten   Scripted  English
# ...

# %%
#(188, 0.39586345557259445), (4632, 0.390094748802747), (790, 0.38437110679803665), (3204, 0.3805471775086832), (3097, 0.375624113212674)
lst=[]
arr=(188, 0.39586345557259445), (4632, 0.390094748802747), (790, 0.38437110679803665), (3204, 0.3805471775086832), (3097, 0.375624113212674)
for i in range(0,5):
    print((arr[i][0]))
    i+=1
# Out:
# 188
# 4632
# 790
# 3204
# 3097

# %%
# Out:
# 790    815
# Name: id, dtype: int64

# %%
new.iloc[0].id
# Out:
# 1

# %%
recomend('Constantine')
# Out:
# Da Vinci's Demons
# Promised Land
# Reaper
# Inspector Gadget
# Nowhere Man
# ["Da Vinci's Demons",
#  'Promised Land',
#  'Reaper',
#  'Inspector Gadget',
#  'Nowhere Man']

# %%
# Out:
# []

# %%
new=safe

# %%
new_df[new_df['name']=="Da Vinci's Demons"]
# Out:
#       id               name                                               tags
# 188  197  Da Vinci's Demons  script drama horror in a world where thought a...

# %%
new_df.head()
# Out:
#    id                name                                               tags
# 0   1      Under the Dome  script drama science-fict thriller under the d...
# 1   2  Person of Interest  script action crime science-fict you are be wa...
# 2   3              Bitten  script drama horror romanc base on the critic ...
# 3   4               Arrow  script drama action science-fict after a viole...
# 4   5      True Detective  script drama crime thriller touch dark and dar...

# %%
recomend('True Detective')
# Out:
# Fargo
# Safe House
# CopStories
# Ojciec Mateusz
# Messiah

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('final_movies_list2f.pkl','wb'))

# %%
new.duplicated().sum()
# Out:
# 0

# %%
new_df=new

# %%
pickle.dump(new.to_dict(),open('Movie_names_original.pkl','wb'))

# %%
new=new_df.drop_duplicates()

# %%
new.shape
# Out:
# (6138, 3)

# %%
new_df.to_dict()['name']
# Out:
# {0: 'Under the Dome',
#  1: 'Person of Interest',
#  2: 'Bitten',
#  3: 'Arrow',
#  4: 'True Detective',
#  5: 'The 100',
#  6: 'Homeland',
#  7: 'Glee',
#  8: 'Revenge',
#  9: 'Grimm',
#  10: 'Gotham',
#  11: 'Lost Girl',
#  12: 'The Flash',
#  13: 'Continuum',
#  14: 'Constantine',
#  15: 'Penny Dreadful',
#  16: 'The Amazing Race',
#  17: 'Supernatural',
#  18: 'The Strain',
#  19: 'The Last Ship',
#  20: 'True Blood',
#  21: 'Once Upon a Time in Wonderland',
#  22: 'Hawaii Five-0',
#  23: 'Hellsing',
#  24: 'Hellsing Ultimate',
#  25: 'Berserk',
#  26: 'Californication',
#  27: 'Vikings',
#  28: 'American Horror Story',
#  29: "Marvel's Agents of S.H.I.E.L.D.",
#  30: 'Fargo',
#  31: 'Hemlock Grove',
#  32: 'Helix',
#  33: 'The Killing',
#  34: 'Intruders',
#  35: 'Z Nation',
#  36: 'Resurrection',
#  37: 'Death Note',
#  38: 'Last Man Standing',
#  39: 'Sleepy Hollow',
#  40: 'Outlander',
#  41: 'Scorpion',
#  42: 'NCIS: New Orleans',
#  43: 'Forever',
# ...

# %%
pickle.dump(final,open('similarity_matrix_original.pkl','wb'))

# %%
df
# Out:
#         id                name         type  \
# 0        1      Under the Dome   [Scripted]
# 1        2  Person of Interest   [Scripted]
# 2        3              Bitten   [Scripted]
# 3        4               Arrow   [Scripted]
# 4        5      True Detective   [Scripted]
# ...    ...                 ...          ...
# 6133  6495              Pocoyo  [Animation]
# 6134  6496              Popeye  [Animation]
# 6135  6497     Worzel Gummidge   [Scripted]
# 6136  6498         Hale & Pace   [Scripted]
# 6137  6499      Eerie, Indiana   [Scripted]
#
#                                   genres  \
# 0     [Drama, Science-Fiction, Thriller]
# 1       [Action, Crime, Science-Fiction]
# 2               [Drama, Horror, Romance]
# 3       [Drama, Action, Science-Fiction]
# 4               [Drama, Crime, Thriller]
# ...                                  ...
# 6133                          [Children]
# 6134                                  []
# 6135             [Drama, Comedy, Family]
# ...

# %%
images=val[['name','image']]

# %%
images
# Out:
#                     name                                              image
# 0         Under the Dome  {'medium': 'https://static.tvmaze.com/uploads/...
# 1     Person of Interest  {'medium': 'https://static.tvmaze.com/uploads/...
# 2                 Bitten  {'medium': 'https://static.tvmaze.com/uploads/...
# 3                  Arrow  {'medium': 'https://static.tvmaze.com/uploads/...
# 4         True Detective  {'medium': 'https://static.tvmaze.com/uploads/...
# ...                  ...                                                ...
# 6133              Pocoyo  {'medium': 'https://static.tvmaze.com/uploads/...
# 6134              Popeye  {'medium': 'https://static.tvmaze.com/uploads/...
# 6135     Worzel Gummidge  {'medium': 'https://static.tvmaze.com/uploads/...
# 6136         Hale & Pace  {'medium': 'https://static.tvmaze.com/uploads/...
# 6137      Eerie, Indiana  {'medium': 'https://static.tvmaze.com/uploads/...
#
# [6138 rows x 2 columns]

# %%
import pickle
pickle.dump(images,open('images_url1.pkl','wb'))

# %%
#finding images
t=images[images['name']=='Promised Land']
nnn=t.values[0]
image_url=nnn[1]['medium']
# Out:
# 'https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg'

# %%
im=pickle.load(open('images_url1.pkl','rb'))

# %%
def findurl(movie):
    movie_names=recomend(movie)
    image_url=[]
    for i in movie_names:
        t=im[im['name']==i]
        nnn=t.values[0]
        image_url.append(nnn[1]['medium'])
    return image_url

# %%
res=findurl('True Detective')
# Out:
# Fargo
# Safe House
# CopStories
# Ojciec Mateusz
# Messiah

# %%
res
# Out:
# ['https://static.tvmaze.com/uploads/images/medium_portrait/267/669639.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/52/130560.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/12/32370.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/23/58716.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/19/48709.jpg']

# %%
image_url
# Out:
# ['https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg',
#  'https://static.tvmaze.com/uploads/images/medium_portrait/302/755459.jpg']

# %%
images
# Out:
#                     name                                              image
# 0         Under the Dome  {'medium': 'https://static.tvmaze.com/uploads/...
# 1     Person of Interest  {'medium': 'https://static.tvmaze.com/uploads/...
# 2                 Bitten  {'medium': 'https://static.tvmaze.com/uploads/...
# 3                  Arrow  {'medium': 'https://static.tvmaze.com/uploads/...
# 4         True Detective  {'medium': 'https://static.tvmaze.com/uploads/...
# ...                  ...                                                ...
# 6133              Pocoyo  {'medium': 'https://static.tvmaze.com/uploads/...
# 6134              Popeye  {'medium': 'https://static.tvmaze.com/uploads/...
# 6135     Worzel Gummidge  {'medium': 'https://static.tvmaze.com/uploads/...
# 6136         Hale & Pace  {'medium': 'https://static.tvmaze.com/uploads/...
# 6137      Eerie, Indiana  {'medium': 'https://static.tvmaze.com/uploads/...
#
# [6138 rows x 2 columns]

# %%
im_dic=im.to_json()

# %%
im_dic
# Out:
# '{"name":{"0":"Under the Dome","1":"Person of Interest","2":"Bitten","3":"Arrow","4":"True Detective","5":"The 100","6":"Homeland","7":"Glee","8":"Revenge","9":"Grimm","10":"Gotham","11":"Lost Girl","12":"The Flash","13":"Continuum","14":"Constantine","15":"Penny Dreadful","16":"The Amazing Race","17":"Supernatural","18":"The Strain","19":"The Last Ship","20":"True Blood","21":"Once Upon a Time in Wonderland","22":"Hawaii Five-0","23":"Hellsing","24":"Hellsing Ultimate","25":"Berserk","26":"Californication","27":"Vikings","28":"American Horror Story","29":"Marvel\'s Agents of S.H.I.E.L.D.","30":"Fargo","31":"Hemlock Grove","32":"Helix","33":"The Killing","34":"Intruders","35":"Z Nation","36":"Resurrection","37":"Death Note","38":"Last Man Standing","39":"Sleepy Hollow","40":"Outlander","41":"Scorpion","42":"NCIS: New Orleans","43":"Forever","44":"Witches of East End","45":"Madam Secretary","46":"Brooklyn Nine-Nine","47":"The Lottery","48":"The Knick","49":"How to Get Away with Murder
# ...

# %%
image_dict=images.to_dict()

# %%
pickle.dump(images.to_dict(),open('images_links.pkl','wb'))

# %%
image_dict[0]['medium']
# Out:
# 'https://static.tvmaze.com/uploads/images/medium_portrait/81/202627.jpg'

# %%
movie_lst=pickle.load(open('Movie_names_original.pkl','rb'))
movie_lst=pd.DataFrame(movie_lst)
similarity=pickle.load(open('similarity_matrix_original.pkl','rb'))
images_url=pickle.load(open('images_url1.pkl','rb'))

# %%
movie_lst.shape
# Out:
# (6138, 3)

# %%
similarity.shape
# Out:
# (6138, 6138)

# %%
images_url.shape
# Out:
# (6138, 2)

# %%
import sqlite3
conn=sqlite3.connect('data.db')
c=conn.cursor()
